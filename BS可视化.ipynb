# %%
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
df = pd.read_csv('C:/Users/jiayi/Desktop/BS/gp/usersum_ln.csv')
corr = df[['expenditure_total','direct_discount','quantity_discount','bundle_discount','coupon_discount']].corr()
corr
# Out:
#                    expenditure_total  direct_discount  quantity_discount  \
# expenditure_total           1.000000         0.346781           0.132044
# direct_discount             0.346781         1.000000          -0.093406
# quantity_discount           0.132044        -0.093406           1.000000
# bundle_discount             0.291235        -0.072198          -0.044575
# coupon_discount            -0.041995         0.079456          -0.001520
#
#                    bundle_discount  coupon_discount
# expenditure_total         0.291235        -0.041995
# direct_discount          -0.072198         0.079456
# quantity_discount        -0.044575        -0.001520
# bundle_discount           1.000000        -0.009437
# coupon_discount          -0.009437         1.000000

# %%
import pandas as pd
data2= pd.read_csv('C:/Users/jiayi/Desktop/BS/gp/user2.csv',usecols=['user_level','plus','education','city_level','expenditure_total'])
data2.describe()
data3 = data2.drop(data2[(data2.user_level < 0)].index)
data3.describe()
# Out:
#           user_level           plus      education     city_level  \
# count  336917.000000  336917.000000  336917.000000  336917.000000
# mean        2.600519       0.240671       2.907090       2.250815
# std         1.041829       0.427491       0.654268       1.068412
# min         0.000000       0.000000       1.000000       1.000000
# 25%         2.000000       0.000000       3.000000       1.000000
# 50%         3.000000       0.000000       3.000000       2.000000
# 75%         4.000000       0.000000       3.000000       3.000000
# max         4.000000       1.000000       4.000000       5.000000
#
#        expenditure_total
# count       3.369170e+05
# mean        1.220023e+02
# std         9.714929e+01
# min         7.110000e-15
# 25%         5.700000e+01
# 50%         9.100000e+01
# 75%         1.580000e+02
# max         6.660000e+02

# %%
df.describe()
# Out:
#        direct_discount  quantity_discount  bundle_discount  coupon_discount  \
# count    336928.000000      336928.000000    336928.000000    336928.000000
# mean         30.159122          14.128814         2.173730         5.066259
# std          42.923563          29.223879        17.583229        17.148420
# min           0.000000           0.000000         0.000000         0.000000
# 25%           0.000000           0.000000         0.000000         0.000000
# 50%          16.000000           0.000000         0.000000         0.000000
# 75%          40.000000          16.500000         0.000000         2.000000
# max         831.000000         400.000000       236.500000       388.000000
#
#        expenditure_total           d_ln           q_ln           b_ln  \
# count       3.369280e+05  336928.000000  336928.000000  336928.000000
# mean        1.220047e+02       2.276408       1.086212       0.095006
# std         9.715128e+01       1.748679       1.689432       0.640778
# ...

# %%
fig10, ax10 = plt.subplots() 
sns.boxplot(x='user_level', y='expenditure_total', data=data3,ax=ax10)
ax10.set_xlabel('user level', fontsize = 12,style='italic')#X轴标签
ax10.set_ylabel('expenditure', fontsize = 12,style='italic')#Y轴标签
plt.savefig('C:/Users/jiayi/Desktop/箱线图1.jpg',dpi=400,bbox_inches='tight')

# %%
fig11, ax11 = plt.subplots() 
sns.boxplot(x='plus', y='expenditure_total', data=data3,ax=ax11)
ax11.set_xlabel('plus', fontsize = 12,style='italic')#X轴标签
ax11.set_ylabel('expenditure', fontsize = 12,style='italic')#Y轴标签
plt.savefig('C:/Users/jiayi/Desktop/箱线图2.jpg',dpi=400,bbox_inches='tight')

# %%
fig12, ax12 = plt.subplots() 
sns.boxplot(x='education', y='expenditure_total', data=data3,ax=ax12)
ax12.set_xlabel('education', fontsize = 12,style='italic')#X轴标签
ax12.set_ylabel('expenditure', fontsize = 12,style='italic')#Y轴标签
plt.savefig('C:/Users/jiayi/Desktop/箱线图3.jpg',dpi=400,bbox_inches='tight')

# %%
fig13, ax13 = plt.subplots() 
sns.boxplot(x='city_level', y='expenditure_total', data=data3,ax=ax13)
ax13.set_xlabel('city level', fontsize = 12,style='italic')#X轴标签
ax13.set_ylabel('expenditure', fontsize = 12,style='italic')#Y轴标签
plt.savefig('C:/Users/jiayi/Desktop/箱线图4.jpg',dpi=400,bbox_inches='tight')

# %%
# 生成热力图
# f,ax = plt.subplots(figsize=(10,5))
# sns.heatmap(corr,annot=True)
# annot=True表示在方格内显示数值
f,ax2 = plt.subplots(figsize=(12,10),nrows=1)#设置图片比例大小
sns.heatmap(corr, annot=True, ax=ax2,cmap='YlGnBu',cbar=True, annot_kws={'size':20,'weight':'bold','style':'oblique'})
ax2.set_title('Heatmap of Sample Correlation Coefficients',weight='bold',fontsize=20,style='italic')
xlabels=['expenditure','direct discount','quantity discount','bundle discount','coupon discount']
ylabels=['expenditure','direct discount','quantity discount','bundle discount','coupon discount']
ax2.set_yticklabels(ylabels, style='italic')#设置坐标轴刻度标签，可选择字体风格、大小等等
ax2.set_xticklabels(xlabels, style='italic')
ax2.tick_params(labelsize=15)
plt.yticks(rotation=45)#设置刻度标签旋转角度
plt.xticks(rotation=45)
plt.savefig('C:/Users/jiayi/Desktop/热力图.jpg',dpi=400,bbox_inches='tight')#设置输出图片像素#解决出框！！！qaq

# %%
import matplotlib.cm as cm
# %matplotlib inline
plt.rcParams['axes.unicode_minus']=False 
def DrawBubble(data):#气泡图
    sns.set(style = "whitegrid")#设置样式
    d = data#数据来源
    x = d.std_recency#X轴数据
    y = d.std_ordertimes#Y轴数据
    z = d.std_expenditure#用来调整各个点的大小s
    l = d.labelnum#用以给每组设置不同颜色
    cm = plt.cm.get_cmap('coolwarm')
    fig,ax = plt.subplots(figsize = (12,10))
    #注意s离散化的方法，因为需要通过点的大小来直观感受其所表示的数值大小
    #我所使用的是当前点的数值减去集合中的最小值后+0.1再*1000
    #参数是X轴数据、Y轴数据、各个点的大小、各个点的颜色 color = color_list[colordict[l] % len(color_list)]   c = z, cmap = cm,
    bubble = ax.scatter(x, y , s = (z - np.min(z) + 0.1) * 1000, c = l, cmap =cm, linewidth = 0.5, alpha = 0.5)#(z - np.min(z) + 0.1) * 1000
    ax.grid()
    cbar = fig.colorbar(bubble)#
    cbar.set_ticks(np.linspace(0,7,8))  
    cbar.set_ticklabels( ( 'R0F0M0','R1F0M0','R0F1M0','R1F1M0','R0F0M1','R1F0M1','R0F1M1','R1F1M1')) 
    ax.set_xlabel('Recency', fontsize = 15)#X轴标签
    ax.set_ylabel('Frequency', fontsize = 15)#Y轴标签
    plt.savefig('C:/Users/maggi/Desktop/2气泡图.jpg', dpi=1000)
    plt.show()
if __name__=='__main__':
    DrawBubble(df)#气泡图

# %%
#散点图
sns.set(style = "whitegrid")
fig,ax = plt.subplots(figsize = (12,10))
sns.scatterplot(x=df['direct_discount_per_unit'], y=df['expenditure_total'],linewidth = 0.5, alpha = 0.5)
sns.regplot(x=df['direct_discount_per_unit'], y=df['expenditure_total'])
ax.set_xlabel('direct discount', fontsize = 20,style='italic')#X轴标签
ax.set_ylabel('expenditure', fontsize = 20,style='italic')#Y轴标签
plt.savefig('C:/Users/jiayi/Desktop/散点e-d.jpg',dpi=400,bbox_inches='tight')
# Out:
# D:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.set(style = "whitegrid")
fig,ax = plt.subplots(figsize = (12,10))
sns.scatterplot(x=df['quantity_discount_per_unit'], y=df['expenditure_total'],linewidth = 0.5, alpha = 0.5)
sns.regplot(x=df['quantity_discount_per_unit'], y=df['expenditure_total'])
ax.set_xlabel('quantity discount', fontsize = 20,style='italic')#X轴标签
ax.set_ylabel('expenditure', fontsize = 20,style='italic')#Y轴标签
plt.savefig('C:/Users/jiayi/Desktop/散点e-q.jpg',dpi=400,bbox_inches='tight')
# Out:
# D:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.set(style = "whitegrid")
fig,ax = plt.subplots(figsize = (12,10))
sns.scatterplot(x=df['bundle_discount_per_unit'], y=df['expenditure_total'],linewidth = 0.5, alpha = 0.5)
sns.regplot(x=df['bundle_discount_per_unit'], y=df['expenditure_total'])
ax.set_xlabel('bundle discount', fontsize = 20,style='italic')#X轴标签
ax.set_ylabel('expenditure', fontsize = 20,style='italic')#Y轴标签
plt.savefig('C:/Users/jiayi/Desktop/散点e-b.jpg',dpi=400,bbox_inches='tight')
# Out:
# D:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.set(style = "whitegrid")
fig,ax = plt.subplots(figsize = (12,10))
sns.scatterplot(x=df['coupon_discount_per_unit'], y=df['expenditure_total'],linewidth = 0.5, alpha = 0.5)
sns.regplot(x=df['coupon_discount_per_unit'], y=df['expenditure_total'])
ax.set_xlabel('coupon discount', fontsize = 20,style='italic')#X轴标签
ax.set_ylabel('expenditure', fontsize = 20,style='italic')#Y轴标签
plt.savefig('C:/Users/jiayi/Desktop/散点e-c.jpg',dpi=400,bbox_inches='tight')
# Out:
# D:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
def f(x):
    if x == 0:
        return 0
    else:
        return 1

df['direct_discount_01'] = df['direct_discount_per_unit'].apply(lambda x:f(x))
sns.set(style = "whitegrid")
fig,ax = plt.subplots(figsize = (12,10))
sns.scatterplot(x=df['bundle_discount_per_unit'], y=df['expenditure_total'],hue=df['direct_discount_01'],linewidth = 0.5, alpha = 0.5)
sns.regplot(x=df['bundle_discount_per_unit'], y=df['expenditure_total'])
ax.set_xlabel('bundle discount', fontsize = 20,style='italic')#X轴标签
ax.set_ylabel('expenditure', fontsize = 20,style='italic')#Y轴标签
plt.savefig('C:/Users/jiayi/Desktop/b-d.jpg',dpi=400,bbox_inches='tight')
# Out:
# D:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
def f(x):
    if x == 0:
        return 0
    else:
        return 1

df['bundle_discount_01'] = df['bundle_discount_per_unit'].apply(lambda x:f(x))
sns.set(style = "whitegrid")
fig,ax = plt.subplots(figsize = (12,10))
sns.scatterplot(x=df['direct_discount_per_unit'], y=df['expenditure_total'],hue=df['bundle_discount_01'],linewidth = 0.5, alpha = 0.5)
sns.regplot(x=df['direct_discount_per_unit'], y=df['expenditure_total'])
ax.set_xlabel('direct discount', fontsize = 20,style='italic')#X轴标签
ax.set_ylabel('expenditure', fontsize = 20,style='italic')#Y轴标签
plt.savefig('C:/Users/jiayi/Desktop/d-b.jpg',dpi=400,bbox_inches='tight')
# Out:
# D:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
def f(x):
    if x == 0:
        return 0
    else:
        return 1

df['coupon_discount_01'] = df['coupon_discount_per_unit'].apply(lambda x:f(x))
sns.set(style = "whitegrid")
fig,ax = plt.subplots(figsize = (12,10))
sns.scatterplot(x=df['direct_discount_per_unit'], y=df['expenditure_total'],hue=df['coupon_discount_01'],linewidth = 0.5, alpha = 0.5)
sns.regplot(x=df['direct_discount_per_unit'], y=df['expenditure_total'])
ax.set_xlabel('direct discount', fontsize = 20,style='italic')#X轴标签
ax.set_ylabel('expenditure', fontsize = 20,style='italic')#Y轴标签
plt.savefig('C:/Users/jiayi/Desktop/d-c.jpg',dpi=400,bbox_inches='tight')
# Out:
# D:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
def f(x):
    if x == 0:
        return 0
    else:
        return 1

df['direct_discount_01'] = df['direct_discount_per_unit'].apply(lambda x:f(x))
sns.set(style = "whitegrid")
fig,ax = plt.subplots(figsize = (12,10))
sns.scatterplot(x=df['coupon_discount_per_unit'], y=df['expenditure_total'],hue=df['direct_discount_01'],linewidth = 0.5, alpha = 0.5)
sns.regplot(x=df['coupon_discount_per_unit'], y=df['expenditure_total'])
ax.set_xlabel('coupon discount', fontsize = 20,style='italic')#X轴标签
ax.set_ylabel('expenditure', fontsize = 20,style='italic')#Y轴标签
plt.savefig('C:/Users/jiayi/Desktop/d-c.jpg',dpi=400,bbox_inches='tight')
# Out:
# D:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df_d = df.drop(df[(df.direct_discount_per_unit == 0)].index)
df_d.describe()
# Out:
#           Unnamed: 0   Unnamed: 0.1  direct_discount_per_unit  \
# count  244849.000000  244849.000000             244849.000000
# mean   168449.946551  168449.946551                 41.500895
# std     97285.665260   97285.665260                 45.438010
# min         0.000000       0.000000                  0.020000
# 25%     84325.000000   84325.000000                 11.000000
# 50%    168381.000000  168381.000000                 21.000000
# 75%    252750.000000  252750.000000                 60.000000
# max    336927.000000  336927.000000                831.000000
#
#        quantity_discount_per_unit  bundle_discount_per_unit  \
# count               244849.000000             244849.000000
# mean                    14.133685                  0.376444
# std                     29.932889                  7.452262
# min                      0.000000                  0.000000
# 25%                      0.000000                  0.000000
# ...

# %%
def f(x):
    if x <= 21:
        return 0
    else:
        return 1

df_d['direct_discount_01'] = df_d['direct_discount_per_unit'].apply(lambda x:f(x))
sns.set(style = "whitegrid")
fig,ax = plt.subplots(figsize = (12,10))
sns.scatterplot(x=df_d['bundle_discount_per_unit'], y=df_d['expenditure_total'],hue=df_d['direct_discount_01'],linewidth = 0.5, alpha = 0.5)
sns.regplot(x=df_d['bundle_discount_per_unit'], y=df_d['expenditure_total'])
ax.set_xlabel('bundle discount', fontsize = 20,style='italic')#X轴标签
ax.set_ylabel('expenditure', fontsize = 20,style='italic')#Y轴标签
plt.savefig('C:/Users/jiayi/Desktop/b-d2.jpg',dpi=400,bbox_inches='tight')
# Out:
# D:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
